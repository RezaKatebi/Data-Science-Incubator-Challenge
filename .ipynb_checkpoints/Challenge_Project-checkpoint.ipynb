# %% [markdown]
# # Image recognition with CNN Neural Network on Fashion dataset
# ## Author: Reza Katebi
#
# ## Motivation
# In recent years, image recognition techniques are becoming vitally important in fields ranging from online shopping to defense sector. By recent developments of the machine learning and deep leaning algorithms, we can classify images with more accuracy. In this project, our purpose is to design a classifier for the images of the cloths that uses Convolutional Neural Networks (CNN) that are multilayer networks that learn from a set of training data provided with the labels and then predict the classes of the unseen test data and report the accuracy of the prediction. The data used here is a very limited dataset and we hope to expand this dataset and use reinforcement learning to design a live version that can predict with more accuracy by having access to more data and do live predictions.
# ### Dataset
# In this project, we are going to use deep naural netwoks to do image recognition for [Fashion](https://github.com/zalandoresearch/fashion-mnist) dataset. The dataset is not that trivial to work with because it has more comliacated shapes. This dataset contains $60000$ trianing and $10000$ testing images with $28 \times 28$ pixels. In this dataset, each training and testing sample is assgined to one of the following labels:
#
# Label         | Description
# ------------- | -------------
#     0         | T-shirt/top
#     1         | Trouser
#     2         | Pullover
#     3         | Dress
#     4         | Coat
#     5         | Sandal
#     6         | Shirt
#     7         | Sneaker
#     8         | Bag
#     9         | Ankle boot

# %% [markdown]
# ###  Reading datasets and libraries
# In this part, we are going to fist read the dataset and the necessary libraries.

# %%
import numpy as np
import tensorflow as tf 
import matplotlib.pyplot as plt
# %matplotlib inline
sess = tf.InteractiveSession()
from tensorflow.examples.tutorials.mnist import input_data
data = input_data.read_data_sets('data/fashion',one_hot = True)
# Out:
# Extracting data/fashion/train-images-idx3-ubyte.gz
# Extracting data/fashion/train-labels-idx1-ubyte.gz
# Extracting data/fashion/t10k-images-idx3-ubyte.gz
# Extracting data/fashion/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# Now, let's take a loo at some sample images from the training dataset.

# %%
fig, axes = plt.subplots(3,4, figsize=(10,10))
for row in axes:
    for ax in row:
        batch_X, batch_Y = data.train.next_batch(100)
        image = batch_X[0].reshape(28,28)
        ax.imshow(image, cmap = 'gray')

# %% [markdown]
# In following, we have designed a normal Softmax regression that uses a Gradient Descent Optimzing algorithm to reduce the cost and then we have predicted the test data with $84.22\%$ accuracy that is very bad.

# %%
x = tf.placeholder(tf.float32, [None, 784])
y_ = tf.placeholder(tf.float32, [None, 10])

W = tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))
y = tf.matmul(x,W) + b

sess.run(tf.global_variables_initializer())
cross_entropy = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y))

train_step = tf.train.GradientDescentOptimizer(0.05).minimize(cross_entropy)

for _ in range(20000):
    batch_x,batch_y = data.train.next_batch(100)
    train_step.run(feed_dict={x: batch_x, y_: batch_y})
    
correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

print(accuracy.eval(feed_dict={x: data.test.images, y_: data.test.labels}))
# Out:
# 0.8447

# %% [markdown]
# ### CNN neural network approach:
# As we have shown in the last section the normal Softmax Regression has very bad accuracy in predicting and for that reason we are going to use a multilayer neural network. Here we are going to use a three layer naural network.First, we are going to define some useful functions. In order to acoid dead neurons we are going to initialize the weights and biases with very small values because we are using Relu acctivation fuctions. In order to handle the oundries we are using vanilla version and pooling over the $2\times2$ blocks.

# %%
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)


def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],
                          strides=[1, 2, 2, 1], padding='SAME')

# %% [markdown]
# ### First layer
# Our first layer consists of convolution followed by max pooling. The convolution consists of 32 features for each  $5\times5$ patch. The shape of the weights is $[5,5,1,32]$ where the fist two are patch sizes, the third is the number of input channels and the forth is the output size. We then convolve the reshped image using ReLu and apply maxpool again that reduces the image size to $14\times14$.

# %%
W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])

# %%
x_image = tf.reshape(x, [-1, 28, 28, 1])

# %%
h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

# %% [markdown]
# ## Second layer
# Now we are making the network deeper, the second layer takes the ouput of the first layer as input with 64 features for each $5\times5$ patch.

# %%
W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])

h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

# %% [markdown]
# ## Fully connected layer
# For the last layer we are using $7 \times 7 \times 64 = 1024$ fully connected neurons. Then we are applying dropout to reduce the overfitting before the output layer. Dropout works better we we have more layers.

# %%
W_fc1 = weight_variable([7 * 7 * 64, 1024])
b_fc1 = bias_variable([1024])

h_pool2_flat = tf.reshape(h_pool2, [-1, 7*7*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

# %%
keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# %% [markdown]
# ## Read-out layer
# Here we are using just a one-layer Softmax Regression to output the results.

# %%
W_fc2 = weight_variable([1024, 10])
b_fc2 = bias_variable([10])

y_conv = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

# %% [markdown]
# ## Perform the training
# Here we are using `AdamOptimizer` as the training method that gives us accuracy of $91\%$.

# %%
cross_entropy = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y_conv))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
epochs = []
accuracy_range = []
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(20000):
        batch = data.train.next_batch(50)
        if i % 100 == 0:
            train_accuracy = accuracy.eval(feed_dict={
                x: batch[0], y_: batch[1], keep_prob: 1.0})
            print('step %d, training accuracy %g' % (i, train_accuracy))
            epochs = np.append(epochs,i)
            accuracy_range = np.append(accuracy_range,train_accuracy)
        train_step.run(feed_dict={x: batch[0], y_: batch[1], keep_prob: 0.5})

    print('test accuracy %g' % accuracy.eval(feed_dict={
        x: data.test.images, y_: data.test.labels, keep_prob: 1.0}))
# Out:
# step 0, training accuracy 0
# step 100, training accuracy 0.62
# step 200, training accuracy 0.72
# step 300, training accuracy 0.84
# step 400, training accuracy 0.74
# step 500, training accuracy 0.84
# step 600, training accuracy 0.84
# step 700, training accuracy 0.86
# step 800, training accuracy 0.92
# step 900, training accuracy 0.9
# step 1000, training accuracy 0.82
# step 1100, training accuracy 0.92
# step 1200, training accuracy 0.86
# step 1300, training accuracy 0.82
# step 1400, training accuracy 0.92
# step 1500, training accuracy 0.84
# step 1600, training accuracy 0.86
# step 1700, training accuracy 0.88
# step 1800, training accuracy 0.82
# step 1900, training accuracy 0.82
# step 2000, training accuracy 0.82
# step 2100, training accuracy 0.88
# step 2200, training accuracy 0.88
# step 2300, training accuracy 0.9
# step 2400, training accuracy 0.88
# step 2500, training accuracy 0.9
# step 2600, training accuracy 0.9
# step 2700, training accuracy 0.86
# ...

# %%
plt.plot(epochs,accuracy_range)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("The accuracy vs number of epochs")

# %% [markdown]
# ## Conclusions
# I have developed a model for image recognition. I am proposing to make a better model that is going to recommend products to customers based on the provided image. Also, it can help to label the images of the product with the reasonable prices and give customer variety of choices which is very important for customer satisfaction in online marketing. I hope that I will have the opportunity to work on such an application during the data science incubator fellowship program.
